# %%
import tushare as ts

data=ts.get_hist_data('hs300', ktype='W')#获取沪深300指数k线数据
data = data.iloc[::-1]
data
# Out:
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#                open     high    close      low     volume  price_change  \
# date
# 2005-04-08   984.66  1003.70  1003.45   979.53   147625.0          0.00
# 2005-04-15  1003.88  1008.73   974.08   971.93   655883.0        -29.37
# 2005-04-22   970.91   970.91   939.22   934.96   472916.0        -34.86
# 2005-04-29   935.99   945.50   932.40   914.83   595202.0         -6.82
# 2005-05-13   934.65   937.39   887.54   875.58   495390.0        -44.86
# ...             ...      ...      ...      ...        ...           ...
# 2022-03-04  4563.74  4623.43  4496.43  4481.49  6373972.0        -76.99
# 2022-03-11  4462.52  4462.52  4306.52  4068.19  8219602.0       -189.91
# 2022-03-18  4248.15  4302.74  4265.90  3942.86  8575996.0        -40.62
# 2022-03-25  4280.14  4287.82  4174.57  4173.93  5882342.5        -91.33
# 2022-04-01  4128.84  4290.67  4276.16  4091.30  6248942.5        101.59
#
# ...
